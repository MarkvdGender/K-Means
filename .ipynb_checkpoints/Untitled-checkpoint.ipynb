# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statistics

sns.set()

# %%
from sklearn.cluster import KMeans

# %%
import requests
from datetime import datetime, timedelta

# %% [markdown]
# # Inladen van de Trips

# %%
r = requests.get("http://localhost:8080/trip/all")

# %%
trips = r.json()

# %%
def fuse_trips(trip1, trip2):
    measure_distance_metres = trip1['MeasureDistanceMetres']+trip2['MeasureDistanceMetres']
    measure_co2_grams = trip1['MeasureCo2Grams']+trip2['MeasureCo2Grams']
    measure_minutes_exercise = trip1['MeasureMinutesExercise']+trip2['MeasureMinutesExercise']
    measure_co2_grams_km = measure_co2_grams/(measure_distance_metres/1000)

    trip_dict = {
        "MeasureDistanceMetres": measure_distance_metres,
        "MeasureCo2Grams": measure_co2_grams,
        "MeasureMinutesExercise": measure_minutes_exercise,
        "MeasureCo2GramsKm": measure_co2_grams_km,
        "EventStartDateTimeUtc" : start.strftime('%Y-%m-%d %H:%M:%S'),
        "EventEndDateTimeUtc": end.strftime('%Y-%m-%d %H:%M:%S')}
    
    return trip_dict

# %%
def trip_merge(lijst):
    global start
    global end

    for i in range (len(lijst)):
        start = datetime.strptime(lijst[i]['EventStartDateTimeUtc'], '%Y-%m-%d %H:%M:%S')
        if(abs(end-start) <= timedelta(minutes=5) and i != 0):
            trip1, trip2 = lijst[i-1], lijst[i]
            trip = fuse_trips(trip1, trip2)
            lijst.pop(i), lijst.pop(i-1)
            lijst.append(trip)
            end = datetime.strptime(lijst[i]['EventEndDateTimeUtc'], '%Y-%m-%d %H:%M:%S')
            return trip_merge(lijst)
        else:
            end = datetime.strptime(lijst[i]['EventEndDateTimeUtc'], '%Y-%m-%d %H:%M:%S')
            
# end of recursion
    return lijst

# %%
trips = trip_merge(trips)

# %%
trip_df = pd.DataFrame()
for trip in trips:
    trip_df = trip_df.append(trip, ignore_index=True)

# %%
trip_df
# Out:
#      EventEndDateTimeLocal  EventEndDateTimeUtc   EventId EventModality  \
# 0      2020-07-01 15:24:00  2020-07-01 13:24:49  559260.0           Car
# 1      2020-07-01 13:01:00  2020-07-01 11:01:00  559261.0         Other
# 2      2020-07-01 16:09:00  2020-07-01 14:09:31  559262.0       Bicycle
# 3      2020-07-01 21:49:00  2020-07-01 19:49:46  559263.0         Train
# 4      2020-07-02 22:00:00  2020-07-02 20:00:18  559264.0           Car
# ...                    ...                  ...       ...           ...
# 9415                   NaN  2020-07-04 12:19:16       NaN           NaN
# 9416                   NaN  2020-07-22 16:31:12       NaN           NaN
# 9417                   NaN  2020-07-22 19:26:19       NaN           NaN
# 9418                   NaN  2020-07-22 20:36:25       NaN           NaN
# 9419                   NaN  2020-07-03 08:30:36       NaN           NaN
#
#      EventOffPeak  EventPurpose EventStartDateTimeLocal EventStartDateTimeUtc  \
# 0           FALSE  BusinessTrip     2020-07-01 15:07:00   2020-07-01 13:07:07
# 1           FALSE  BusinessTrip     2020-07-01 12:40:00   2020-07-01 10:40:05
# 2           FALSE  BusinessTrip     2020-07-01 15:54:00   2020-07-01 13:54:34
# 3           FALSE  PersonalTrip     2020-07-01 21:30:00   2020-07-01 19:30:09
# 4           FALSE     Commuting     2020-07-02 21:31:00   2020-07-02 19:31:58
# ...           ...           ...                     ...                   ...
# 9415          NaN           NaN                     NaN   2020-07-04 12:19:16
# 9416          NaN           NaN                     NaN   2020-07-22 16:35:52
# 9417          NaN           NaN                     NaN   2020-07-22 19:30:44
# 9418          NaN           NaN                     NaN   2020-07-22 20:36:25
# 9419          NaN           NaN                     NaN   2020-07-03 08:30:36
#
#       EventType                      MaskedUserId  MeasureAverageKMH  \
# 0     TripEvent  085F0044F6C691577272759135CA7A7B               37.0
# 1     TripEvent  085F0044F6C691577272759135CA7A7B                0.0
# 2     TripEvent  085F0044F6C691577272759135CA7A7B               15.0
# 3     TripEvent  085F0044F6C691577272759135CA7A7B               73.0
# 4     TripEvent  085F0044F6C691577272759135CA7A7B              199.0
# ...         ...                               ...                ...
# 9415        NaN                               NaN                NaN
# 9416        NaN                               NaN                NaN
# 9417        NaN                               NaN                NaN
# 9418        NaN                               NaN                NaN
# 9419        NaN                               NaN                NaN
#
#       MeasureCo2Grams  MeasureCo2GramsKm  MeasureDistanceMetres  \
# 0              2027.0         181.000000                11200.0
# 1                 0.0           0.000000                    0.0
# 2                 0.0           0.000000                 3700.0
# 3                 0.0           0.000000                24200.0
# 4             16942.0         181.000000                93600.0
# ...               ...                ...                    ...
# 9415           3258.0         175.822990                18530.0
# 9416              0.0           0.000000                99750.0
# 9417              0.0           0.000000               103200.0
# 9418            380.0         145.038168                 2620.0
# 9419              0.0           0.000000                 4900.0
#
#       MeasureMinutesExercise
# 0                        0.0
# 1                        0.0
# 2                       15.0
# 3                        0.0
# 4                        0.0
# ...                      ...
# 9415                     2.0
# 9416                     3.0
# 9417                    20.0
# 9418                     3.0
# 9419                    39.0
#
# [9420 rows x 15 columns]

# %% [markdown]
# # K-means

# %%
plt.title('Histogram')
plt.xlabel('MeasureDistanceMetres')
plt.ylabel('Trips')
plt.hist(trip_df['MeasureDistanceMetres'], 100)
plt.show()

# %%
def train_kmeans(clusters, df):
    return KMeans(n_clusters = clusters, random_state=0).fit(df)

# %%
kmeans_df = trip_df.drop(['MaskedUserId', 'EventEndDateTimeLocal', 'EventEndDateTimeUtc', 'EventId', 'EventModality',
                        'EventOffPeak', 'EventPurpose', 'EventStartDateTimeLocal', 'EventStartDateTimeUtc', 'EventType',
                          'MeasureAverageKMH', 'MeasureCo2GramsKm', 'MeasureCo2Grams', 'MeasureMinutesExercise'], axis=1)

# %%
inertias=[]

for i in range(1,10):
    kmodel = train_kmeans(i, kmeans_df)
    inertias.append(kmodel.inertia_)

# %%
plt.plot(range(1,10), inertias, 'bx-') 
plt.xlabel('Values of K') 
plt.ylabel('Inertia') 
plt.title('The Elbow Method using Inertia') 
plt.show()

# %%
kmodel = train_kmeans(4, kmeans_df)

# %%
trip_df['groep'] = kmodel.labels_

# %%
def plot(x, y, highlight):
    plt.scatter(x, y,c=highlight, cmap='plasma')
    plt.xlim(0, max(x))
    plt.ylim(0, max(y))

    plt.show()

# %%
plot(trip_df['MeasureDistanceMetres'], trip_df['MeasureCo2Grams'], trip_df['groep'])

# %%
cluster0_df = trip_df[trip_df['groep']==0]
cluster1_df = trip_df[trip_df['groep']==1]
cluster2_df = trip_df[trip_df['groep']==2]

# %%
kmeans_df2 = cluster2_df.drop(['MaskedUserId', 'EventEndDateTimeLocal', 'EventEndDateTimeUtc', 'EventId', 'EventModality',
                        'EventOffPeak', 'EventPurpose', 'EventStartDateTimeLocal', 'EventStartDateTimeUtc', 'EventType',
                          'MeasureAverageKMH', 'MeasureDistanceMetres', 'MeasureCo2GramsKm',
                               'MeasureMinutesExercise'], axis=1)

# %%
inertias=[]

for i in range(1,10):
    kmodel = train_kmeans(i, kmeans_df2)
    inertias.append(kmodel.inertia_)

# %%
plt.plot(range(1,10), inertias, 'bx-') 
plt.xlabel('Values of K') 
plt.ylabel('Inertia') 
plt.title('The Elbow Method using Inertia') 
plt.show()

# %%
kmodel = train_kmeans(3, kmeans_df2)

# %%
cluster2_df['subgroep'] = kmodel.labels_
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
len(cluster2_df)
# Out:
# 42

# %%
plot(cluster2_df['MeasureDistanceMetres'], cluster2_df['MeasureCo2Grams'], cluster2_df['groep'])

# %% [markdown]
# # Correlatie-onderzoek

# %%
def modality_corr(df):
    s_corr = df.EventModality.str.get_dummies(sep=' ').corrwith(df.MeasureCo2Grams/df.MeasureCo2Grams.max())
    print (s_corr)

# %%
modality_corr(cluster0_df)
# Out:
# Bicycle           -0.326552
# Car                0.532347
# Carpool           -0.007709
# ElectricCar       -0.201969
# Ferry             -0.087605
# Other             -0.102373
# PublicTransport   -0.044510
# SharedCar          0.058304
# Train             -0.352091
# dtype: float64

# %%
cluster0_df.corr().style.background_gradient(cmap='plasma')
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow0_col0 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow0_col1 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow0_col2 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow0_col3 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow0_col4 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow0_col5 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow0_col6 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow1_col0 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow1_col1 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow1_col2 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow1_col3 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow1_col4 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow1_col5 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow1_col6 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow2_col0 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow2_col1 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow2_col2 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow2_col3 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow2_col4 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_9a45b8fa_56ac_11eb_9dae_5cf37096774crow2_col5 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T