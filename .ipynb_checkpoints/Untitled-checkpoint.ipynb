# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statistics

sns.set()

# %%
from sklearn.cluster import KMeans

# %%
import requests
from datetime import datetime, timedelta

# %% [markdown]
# # Inladen van de Trips

# %%
def fuse_trips(trip1, trip2):
    measure_distance_metres = trip1['MeasureDistanceMetres']+trip2['MeasureDistanceMetres']
    measure_co2_grams = trip1['MeasureCo2Grams']+trip2['MeasureCo2Grams']
    measure_minutes_exercise = trip1['MeasureMinutesExercise']+trip2['MeasureMinutesExercise']
    measure_co2_grams_km = measure_co2_grams/(measure_distance_metres/1000)

    trip_dict = {
        "MeasureDistanceMetres": measure_distance_metres,
        "MeasureCo2Grams": measure_co2_grams,
        "MeasureMinutesExercise": measure_minutes_exercise,
        "MeasureCo2GramsKm": measure_co2_grams_km,
        "EventStartDateTimeUtc" : start.strftime('%Y-%m-%d %H:%M:%S'),
        "EventEndDateTimeUtc": end.strftime('%Y-%m-%d %H:%M:%S'),
        "EventModality": 'Combined'}
    
    return trip_dict

# %%
def trip_merge(lijst):
    global start
    global end 
    end = datetime.now()

    for i in range (len(lijst)):
        start = datetime.strptime(lijst[i]['EventStartDateTimeUtc'], '%Y-%m-%d %H:%M:%S')
        if(abs(start-end) <= timedelta(minutes=20) and i != 0):
            trip1, trip2 = lijst[i-1], lijst[i]
            trip = fuse_trips(trip1, trip2)
            lijst.pop(i), lijst.pop(i-1)
            lijst.append(trip)
            end = datetime.strptime(lijst[i]['EventEndDateTimeUtc'], '%Y-%m-%d %H:%M:%S')
            return trip_merge(lijst)
        else:
            end = datetime.strptime(lijst[i]['EventEndDateTimeUtc'], '%Y-%m-%d %H:%M:%S')
            
# end of recursion
    return lijst

# %%
r = requests.get("http://localhost:8080/trip/all")

# %%
trips = r.json()

# %%
trip_df = pd.DataFrame(trips)

# %%
trip_df
# Out:
#         EventId  EventType EventModality  EventPurpose EventOffPeak  \
# 0         21976  TripEvent       Bicycle  PersonalTrip        FALSE
# 1         21977  TripEvent          Foot  PersonalTrip        FALSE
# 2         21978  TripEvent          Foot  PersonalTrip        FALSE
# 3         21979  TripEvent           Car     Commuting        FALSE
# 4         21980  TripEvent           Car  PersonalTrip        FALSE
# ...         ...        ...           ...           ...          ...
# 166444   640292  TripEvent           Car     Commuting         TRUE
# 166445   640293  TripEvent           Car     Commuting        FALSE
# 166446   640294  TripEvent           Car     Commuting         TRUE
# 166447   640295  TripEvent           Car  PersonalTrip        FALSE
# 166448   640296  TripEvent           Car     Commuting        FALSE
#
#         MeasureDistanceMetres  MeasureAverageKMH  MeasureCo2Grams  \
# 0                        1800               20.0                0
# ...

# %%
trip_df = trip_df.query("EventModality != 'Other'")
trip_df = trip_df.reset_index(drop=True)

# %%
trips = trip_merge(trips)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-264-14c2838ee3b6> in <module>
# ----> 1 trips = trip_merge(trips)
#
# <ipython-input-7-d28399867cdf> in trip_merge(lijst)
#      12             lijst.append(trip)
#      13             end = datetime.strptime(lijst[i]['EventEndDateTimeUtc'], '%Y-%m-%d %H:%M:%S')
# ---> 14             return trip_merge(lijst)
#      15         else:
#      16             end = datetime.strptime(lijst[i]['EventEndDateTimeUtc'], '%Y-%m-%d %H:%M:%S')
#
# <ipython-input-7-d28399867cdf> in trip_merge(lijst)
#      12             lijst.append(trip)
#      13             end = datetime.strptime(lijst[i]['EventEndDateTimeUtc'], '%Y-%m-%d %H:%M:%S')
# ---> 14             return trip_merge(lijst)
#      15         else:
#      16             end = datetime.strptime(lijst[i]['EventEndDateTimeUtc'], '%Y-%m-%d %H:%M:%S')
#
# ...

# %% [markdown]
# # K-means clustering

# %%
def train_kmeans(clusters, df):
    return KMeans(n_clusters = clusters, random_state=0).fit(df)

# %%
def scatterplot(x, y, highlight):
    plt.scatter(x, y,c=highlight, cmap='plasma')
    plt.xlim(0, max(x))
    plt.ylim(0, max(y))

    plt.show()

# %%
def inertias(df, n):
    inertias=[]

    for i in range(1,n):
        kmodel = train_kmeans(i, df)
        inertias.append(kmodel.inertia_)
    
    plt.plot(range(1, n), inertias, 'bx-') 
    plt.xlabel('Values of K') 
    plt.ylabel('Inertia') 
    plt.title('The Elbow Method using Inertia') 
    plt.show()

# %%
kmeans_df = trip_df[['MeasureDistanceMetres']]

# %%
inertias(kmeans_df, 10)

# %%
kmodel_distance = train_kmeans(4, kmeans_df)

# %%
trip_df['distance'] = kmodel.labels_

# %%
scatterplot(trip_df['MeasureDistanceMetres'], trip_df['MeasureCo2Grams'], trip_df['distance'])

# %%
cluster0_df = trip_df.query("distance == 0").reset_index(drop=True)
cluster1_df = trip_df.query("distance == 1").reset_index(drop=True)
cluster2_df = trip_df.query("distance == 2").reset_index(drop=True)
cluster3_df = trip_df.query("distance == 3").reset_index(drop=True)

# %% [markdown]
# ### Korte afstand

# %%
inertias(cluster0_df[['MeasureCo2GramsKm']], 5)

# %%
kmodel_0 = train_kmeans(2, cluster0_df[['MeasureCo2GramsKm']])

# %%
cluster0_df['duurzaamheid'] = kmodel.labels_

# %%
plot(cluster0_df['MeasureDistanceMetres'], cluster0_df['MeasureCo2Grams'], cluster0_df['duurzaamheid'])

# %%
min(cluster0_df.MeasureDistanceMetres)
# Out:
# 0

# %%
max(cluster0_df.MeasureDistanceMetres)
# Out:
# 31800

# %%
cluster0_df.MeasureDistanceMetres.median()
# Out:
# 3400.0

# %%
cluster0_df.MeasureDistanceMetres.mean()
# Out:
# 6446.207724592994

# %%
cluster0_df.EventModality.value_counts().plot(kind='pie')

# %%
cluster0_df.query("duurzaamheid == 0").EventModality.value_counts().plot(kind='pie')

# %%
cluster0_df.query("duurzaamheid == 1").EventModality.value_counts().plot(kind='pie')

# %% [markdown]
# ### Matige afstand

# %%
inertias(cluster1_df[['MeasureCo2GramsKm']], 5)

# %%
kmodel_1 = train_kmeans(2, cluster1_df[['MeasureCo2GramsKm']])

# %%
cluster1_df['duurzaamheid'] = kmodel.labels_

# %%
plot(cluster1_df['MeasureDistanceMetres'], cluster1_df['MeasureCo2Grams'], cluster1_df['duurzaamheid'])

# %%
cluster1_df.EventModality.value_counts().plot(kind='pie')

# %%
cluster1_df.query("duurzaamheid == 0").EventModality.value_counts().plot(kind='pie')

# %%
cluster1_df.query("duurzaamheid == 1").EventModality.value_counts().plot(kind='pie')

# %% [markdown]
# ### Lange afstand

# %%
inertias(cluster2_df[['MeasureCo2GramsKm']], 5)

# %%
kmodel_2 = train_kmeans(2, cluster2_df[['MeasureCo2GramsKm']])

# %%
cluster2_df['duurzaamheid'] = kmodel.labels_

# %%
plot(cluster2_df['MeasureDistanceMetres'], cluster2_df['MeasureCo2Grams'], cluster2_df['duurzaamheid'])

# %%
cluster2_df.EventModality.value_counts().plot(kind='pie')

# %%
cluster2_df.query("duurzaamheid == 0").EventModality.value_counts().plot(kind='pie')

# %%
cluster2_df.query("duurzaamheid == 1").EventModality.value_counts().plot(kind='pie')

# %% [markdown]
# ### Heel lange afstand

# %%
inertias(cluster3_df[['MeasureCo2GramsKm']], 5)

# %%
kmodel_3 = train_kmeans(2, cluster3_df[['MeasureCo2GramsKm']])

# %%
cluster3_df['duurzaamheid'] = kmodel.labels_

# %%
plot(cluster3_df['MeasureDistanceMetres'], cluster3_df['MeasureCo2Grams'], cluster3_df['duurzaamheid'])

# %%
cluster3_df.EventModality.value_counts().plot(kind='pie')

# %%
cluster3_df.query("duurzaamheid == 0").EventModality.value_counts().plot(kind='pie')

# %%
cluster3_df.query("duurzaamheid == 1").EventModality.value_counts().plot(kind='pie')

# %% [markdown]
# # Trip beoordelen

# %%
sample = trips[4]

# %%
sample
# Out:
# {'EventId': 21980,
#  'EventType': 'TripEvent',
#  'EventModality': 'Car',
#  'EventPurpose': 'PersonalTrip',
#  'EventOffPeak': 'FALSE',
#  'MeasureDistanceMetres': 12800,
#  'MeasureAverageKMH': 56.0,
#  'MeasureCo2Grams': 2317,
#  'MeasureCo2GramsKm': 181,
#  'MeasureMinutesExercise': 0,
#  'EventEndDateTimeLocal': '2018-12-06 12:04:00',
#  'EventEndDateTimeUtc': '2018-12-06 12:04:00',
#  'EventStartDateTimeLocal': '2018-12-06 11:50:00',
#  'EventStartDateTimeUtc': '2018-12-06 11:50:00',
#  'MaskedUserId': '9F20ABD7B315137ACAFE79E1DFCF4CD0'}

# %%
distance = kmodel_distance.predict([[sample['MeasureDistanceMetres']]])
duurzaamheid = sample['MeasureCo2GramsKm']
if(distance == 0):
    result = kmodel_0.predict([[duurzaamheid]])
elif(distance == 1):
    result = kmodel_1.predict([[duurzaamheid]])
elif(distance == 2):
    result = kmodel_2.predict([[duurzaamheid]])
elif(distance == 3):
    result = kmodel_3.predict([[duurzaamheid]])

# %%
if(result == 0):
    print("geen duurzame reis")
elif(result == 1):
    print("duurzame reis")
# Out:
# duurzame reis
