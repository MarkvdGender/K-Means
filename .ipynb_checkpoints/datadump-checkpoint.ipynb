# %%
import pandas as pd

# %%
df = pd.read_excel("TripEvents.xlsx")

# %%
df.head()
# Out:
#    EventId  EventType EventModality  EventPurpose  EventOffPeak  \
# 0    21976  TripEvent       Bicycle  PersonalTrip         False
# 1    21977  TripEvent          Foot  PersonalTrip         False
# 2    21978  TripEvent          Foot  PersonalTrip         False
# 3    21979  TripEvent           Car     Commuting         False
# 4    21980  TripEvent           Car  PersonalTrip         False
#
#    MeasureDistanceMetres  MeasureAverageKMH  MeasureCo2Grams  \
# 0                   1800              20.00                0
# 1                    680               5.67                0
# 2                    910               5.06                0
# 3                  13500              61.36             2444
# 4                  12800              55.65             2317
#
#    MeasureCo2GramsKm  MeasureMinutesExercise EventEndDateTimeLocal  \
# 0                  0                       6   2018-09-11 21:22:00
# 1                  0                       7   2018-12-07 10:50:00
# ...

# %%
df2 = pd.read_excel("TransactionEvents.xlsx")

# %%
df2.head()
# Out:
#    AggDatePersonModalityId         EventType AggStartDate AggModality  \
# 0                   450404  TransactionEvent   2019-01-01         Car
# 1                   450418  TransactionEvent   2019-01-01         Car
# 2                   450425  TransactionEvent   2019-01-01         Car
# 3                   450439  TransactionEvent   2019-01-01         Car
# 4                   450446  TransactionEvent   2019-01-01         Car
#
#    AggDistanceMetres  AggDistanceMetresOffPeak  AggTravelDurationMinutes  \
# 0            2319000                         0                         0
# 1                  0                         0                         0
# 2            1111000                         0                         0
# 3            1966000                         0                         0
# 4                  0                         0                         0
#
#    AggAverageKMH  AggCo2Grams  AggCo2GramsKm  ...  AggFuelLiters  \
# ...
